# %%
library(dplyr)
library(data.table)
library(rjson)
library(skimr)
library(tableone)

setwd("~/Desktop/PhD/courses/2025_summer/TDBRAIN/TDBRAIN_participants_V2_data/")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last

# %%
participant <- fread("TDBRAIN_participants_V2.tsv")
participant <- participant %>%
    mutate(across(everything(), ~ stringr::str_replace_all(., "nan", "NA"))) %>%
    mutate(across(everything(), ~ na_if(., "NA")))

data_desc <- fromJSON(file = "TDBRAIN_participants_V2.json")

# %%
adhd <- participant %>% filter(indication == "ADHD" | formal_status == "ADHD" | indication == "HEALTHY")
adhd_treatment <- adhd %>% filter(!is.na(ADHD_pre_Hyp_leading))

dim(adhd)
dim(adhd_treatment)
# Out:
# [1] 252 110
# [1]  72 110

# %%
data_desc_df <- data.frame(
  variable = names(data_desc),
  description = sapply(data_desc, function(x) x$description %||% NA),
  format = sapply(data_desc, function(x) x$format %||% NA),
  levels = sapply(data_desc, function(x) {
    if("levels" %in% names(x)) {
      if(is.list(x$levels)) {
        paste(names(x$levels), x$levels, sep = ": ", collapse = "; ")
      } else {
        as.character(x$levels)
      }
    } else {
      NA
    }
  }),
  stringsAsFactors = FALSE
)

# %%
vars <- data_desc_df %>% filter(!grepl("neoFFI", variable)) %>% filter(!grepl("YBOCS", variable))
vars$variable
# Out:
#  [1] "participant_id" "indication"     "formal Dx"      "Dataset"
#  [5] "Consent"        "sessSeason"     "sessTime"       "Responder"
#  [9] "age"            "gender"         "sessID"         "nrSessions"
# [13] "EC"             "EO"             "avg_rt_oddb_CP" "avg_rt_oddb_FP"
# [17] "n_oddb_CP"      "n_oddb_FP"      "n_oddb_CN"      "n_oddb_FN"
# [21] "avg_rt_wm_CP"   "avg_rt_wm_FP"   "n_wm_CP"        "n_wm_FP"
# [25] "n_wm_CN"        "n_wm_FN"        "cigarette"      "coffee"
# [29] "beer"           "drugs"          "education"      "meal"
# [33] "sleep"          "well"           "vision"         "hearing"
# [37] "Weight"         "Height"         "BDI Pre"        "BDI Post"
# [41] "rTMS PROTOCOL"  "ADHD_pre_Hyp"   "ADHD_pre_Att"   "ADHD_post_Hyp"
# [45] "ADHD_post_Att"  "NF Protocol"

# %%
vars
# Out:
#                variable
# participant_id participant_id
# indication     indication
# formal Dx      formal Dx
# Dataset        Dataset
# Consent        Consent
# sessSeason     sessSeason
# sessTime       sessTime
# Responder      Responder
# age            age
# gender         gender
# sessID         sessID
# nrSessions     nrSessions
# EC             EC
# EO             EO
# avg_rt_oddb_CP avg_rt_oddb_CP
# avg_rt_oddb_FP avg_rt_oddb_FP
# n_oddb_CP      n_oddb_CP
# n_oddb_FP      n_oddb_FP
# n_oddb_CN      n_oddb_CN
# n_oddb_FN      n_oddb_FN
# avg_rt_wm_CP   avg_rt_wm_CP
# avg_rt_wm_FP   avg_rt_wm_FP
# n_wm_CP        n_wm_CP
# n_wm_FP        n_wm_FP
# n_wm_CN        n_wm_CN
# n_wm_FN        n_wm_FN
# cigarette      cigarette
# coffee         coffee
# beer           beer
# drugs          drugs
# education      education
# meal           meal
# sleep          sleep
# well           well
# vision         vision
# hearing        hearing
# Weight         Weight
# Height         Height
# BDI Pre        BDI Pre
# BDI Post       BDI Post
# rTMS PROTOCOL  rTMS PROTOCOL
# ADHD_pre_Hyp   ADHD_pre_Hyp
# ADHD_pre_Att   ADHD_pre_Att
# ADHD_post_Hyp  ADHD_post_Hyp
# ADHD_post_Att  ADHD_post_Att
# NF Protocol    NF Protocol
#                description
# participant_id 8-digit code, unique for each subject
# indication     Indication as described in manuscript
# formal Dx      Formal Diagnosis as described in manuscript
# Dataset        Which publication the session belongs to
# Consent        Confirmation of consent
# sessSeason     Season of the sessions measurment meteorologically (Winter: December 1rst to March 1rst, Spring: March 1rst to June 1rst, Summer: June 1rst to September 1rst, Fall: September 1rst to December 1rst)
# sessTime       measurement in morning <12pm or in the afternoon >12pm
# Responder      response to treatment (for ADHD_NF: either ADHD_post_Hyp or ADHD_post_Att improved with 25%; or for MDD-rTMS: BDI-post improved with more than 50% from BDI-pre);for OCD: post-YBOCS total improved with more than 35% from pre-YBOCS
# age            age of the participant
# gender         sex of the participant
# sessID         session number of the eeg acquisition session (ascending)
# nrSessions     total number of sessions measured for the particular subject
# EC             availability of Eyes Closed condition
# EO             availability of Eyes Open condition
# avg_rt_oddb_CP average reaction time in the auditory oddbal task; correct positives
# avg_rt_oddb_FP average reaction time in the auditory oddbal task; false positives
# n_oddb_CP      number of correct positives in the auditory oddball task
# n_oddb_FP      number of false positives  in the auditory oddball task
# n_oddb_CN      number of correct negatives in the auditory oddball task
# n_oddb_FN      number of false negatives  in the auditory oddball task
# avg_rt_wm_CP   average reaction time in the visual 1-back task; correct positives
# avg_rt_wm_FP   average reaction time in the visual 1-back task; false positives
# n_wm_CP        number of correct positives in the the visual 1-back task
# n_wm_FP        number of false positives  in the the visual 1-back task
# n_wm_CN        number of correct negatives in the the visual 1-back task
# n_wm_FN        number of false negatives  in the visual 1-back task
# cigarette      how many hours ago did you smoke a cigarette? (99 means never)
# coffee         how many hours ago did you consume coffee(99 means never)
# beer           how many hours ago did you consume alcohol? (99 means never)
# drugs          how many hours ago did you take drugs? (99 means never)
# education      what is your education level? maximum of 18 years
# meal           how many hours ago did you have a meal?
# sleep          how many hours did you sleep last night?
# well           how are you feeling overall today compared to other days?
# vision         how is your vision
# hearing        how is your hearing
# Weight         weight
# Height         height
# BDI Pre        Total score of the BDI* at Baseline (*Becks depression inventory - NL)
# BDI Post       Total score of the BDI Post treatment
# rTMS PROTOCOL  the protocol that was used in rTMS treatment
# ADHD_pre_Hyp   total ADHD-RS baseline hyperactivity score
# ADHD_pre_Att   total ADHD-RS baseline inattention score
# ADHD_post_Hyp  total ADHD-RS post treatment hyperactivity score
# ADHD_post_Att  total ADHD-RS post treatment inattention score
# NF Protocol    the protocol that was used in neurofeedback treatment
#                format
# participant_id string
# indication     string
# formal Dx      string
# Dataset        string
# Consent        NA
# sessSeason     string
# sessTime       string
# Responder      NA
# age            float
# gender         NA
# sessID         integer
# nrSessions     integer
# EC             NA
# EO             NA
# avg_rt_oddb_CP NA
# avg_rt_oddb_FP NA
# n_oddb_CP      NA
# n_oddb_FP      NA
# n_oddb_CN      NA
# n_oddb_FN      NA
# avg_rt_wm_CP   NA
# avg_rt_wm_FP   NA
# n_wm_CP        NA
# n_wm_FP        NA
# n_wm_CN        NA
# n_wm_FN        NA
# cigarette      NA
# coffee         NA
# beer           NA
# drugs          NA
# education      NA
# meal           NA
# sleep          NA
# well           NA
# vision         NA
# hearing        NA
# Weight         NA
# Height         NA
# BDI Pre        NA
# BDI Post       NA
# rTMS PROTOCOL  NA
# ADHD_pre_Hyp   NA
# ADHD_pre_Att   NA
# ADHD_post_Hyp  NA
# ADHD_post_Att  NA
# NF Protocol    NA
#                levels
# participant_id NA
# indication     NA
# formal Dx      NA
# Dataset        NA
# Consent        YES
# sessSeason     NA
# sessTime       NA
# Responder      0: non response; 1: response
# age            NA
# gender         0: Female; 1: Male
# sessID         NA
# nrSessions     NA
# EC             0: unavailable; 1: available
# EO             0: unavailable; 1: available
# avg_rt_oddb_CP NA
# avg_rt_oddb_FP NA
# n_oddb_CP      NA
# n_oddb_FP      NA
# n_oddb_CN      NA
# n_oddb_FN      NA
# avg_rt_wm_CP   NA
# avg_rt_wm_FP   NA
# n_wm_CP        NA
# n_wm_FP        NA
# n_wm_CN        NA
# n_wm_FN        NA
# cigarette      NA
# coffee         NA
# beer           NA
# drugs          NA
# education      NA
# meal           NA
# sleep          NA
# well           -2: horrible; -1: less than normal; 1: normal; 2: better than normal; 3: awesome
# vision         0: confirmation of normal or corrected to normal vision
# hearing        0: confirmation of normal hearing
# Weight         NA
# Height         NA
# BDI Pre        NA
# BDI Post       NA
# rTMS PROTOCOL  1: DLPFC 10Hz rTMS Left; 2: DLPFC 1Hz rTMS Right; 3: DLPFC bilateral 1Hz Right & 10Hz Left; 4: SMA 1Hz; 7: 1-Hz TMS SMA; 8: 1-Hz TMS SMA + 1-Hz R-DLPFC
# ADHD_pre_Hyp   NA
# ADHD_pre_Att   NA
# ADHD_post_Hyp  NA
# ADHD_post_Att  NA
# NF Protocol    1: SMR; 2: Theta-Beta-Ratio; 3: Other

# %%
colnames(adhd)
# Out:
#   [1] "participants_ID"       "DISC/REP"              "indication"
#   [4] "formal_status"         "Dataset"               "Consent"
#   [7] "sessSeason"            "sessTime"              "Responder"
#  [10] "Remitter"              "age"                   "gender"
#  [13] "sessID"                "nrSessions"            "EC"
#  [16] "EO"                    "neoFFI_q1"             "neoFFI_q2"
#  [19] "neoFFI_q3"             "neoFFI_q4"             "neoFFI_q5"
#  [22] "neoFFI_q6"             "neoFFI_q7"             "neoFFI_q8"
#  [25] "neoFFI_q9"             "neoFFI_q10"            "neoFFI_q11"
#  [28] "neoFFI_q12"            "neoFFI_q13"            "neoFFI_q14"
#  [31] "neoFFI_q15"            "neoFFI_q16"            "neoFFI_q17"
#  [34] "neoFFI_q18"            "neoFFI_q19"            "neoFFI_q20"
#  [37] "neoFFI_q21"            "neoFFI_q22"            "neoFFI_q23"
#  [40] "neoFFI_q24"            "neoFFI_q25"            "neoFFI_q26"
#  [43] "neoFFI_q27"            "neoFFI_q28"            "neoFFI_q29"
#  [46] "neoFFI_q30"            "neoFFI_q31"            "neoFFI_q32"
#  [49] "neoFFI_q33"            "neoFFI_q34"            "neoFFI_q35"
#  [52] "neoFFI_q36"            "neoFFI_q37"            "neoFFI_q38"
#  [55] "neoFFI_q39"            "neoFFI_q40"            "neoFFI_q41"
#  [58] "neoFFI_q42"            "neoFFI_q43"            "neoFFI_q44"
#  [61] "neoFFI_q45"            "neoFFI_q46"            "neoFFI_q47"
#  [64] "neoFFI_q48"            "neoFFI_q49"            "neoFFI_q50"
#  [67] "neoFFI_q51"            "neoFFI_q52"            "neoFFI_q53"
#  [70] "neoFFI_q54"            "neoFFI_q55"            "neoFFI_q56"
#  [73] "neoFFI_q57"            "neoFFI_q58"            "neoFFI_q59"
#  [76] "neoFFI_q60"            "avg_rt_oddb_CP"        "avg_rt_oddb_FP"
#  [79] "n_oddb_CP"             "n_oddb_FP"             "n_oddb_CN"
#  [82] "n_oddb_FN"             "avg_rt_wm_CP"          "avg_rt_wm_FP"
#  [85] "n_wm_CP"               "n_wm_FP"               "n_wm_CN"
#  [88] "n_wm_FN"               "cigarette"             "coffee"
#  [91] "beer"                  "drugs"                 "education"
#  [94] "meal"                  "sleep"                 "well"
#  [97] "vision"                "hearing"               "Weight (kg)"
# [100] "Height (cm)"           "BDI_pre"               "BDI_post"
# [103] "rTMS PROTOCOL"         "ADHD_pre_Hyp_leading"  "ADHD_pre_Att_leading"
# [106] "ADHD_post_Att_leading" "ADHD_post_Hyp_leading" "NF Protocol"
# [109] "YBOCS_pre"             "YBOCS_post"

# %%
table(adhd$Remitter)
# Out:
#  0  1
# 23 43

# %%
demographics <- adhd %>% 
    select(participants_ID, indication, formal_status, Dataset, sessSeason, sessTime,
           Responder, Remitter, age, gender, nrSessions,
           cigarette, coffee, beer, drugs, education, meal, sleep, 
           well, vision, hearing, "Weight (kg)", "Height (cm)",
           BDI_pre, BDI_post,
           ADHD_pre_Hyp_leading, ADHD_pre_Att_leading, 
           ADHD_post_Hyp_leading, ADHD_post_Att_leading, 
           `NF Protocol`, `rTMS PROTOCOL`,
           # Cognitive performance variables
           avg_rt_oddb_CP, avg_rt_oddb_FP, n_oddb_CP, n_oddb_FP, n_oddb_CN, n_oddb_FN,
           avg_rt_wm_CP, avg_rt_wm_FP, n_wm_CP, n_wm_FP, n_wm_CN, n_wm_FN) %>%
    mutate(
        # Convert numeric variables
        age = as.numeric(age),
        nrSessions = as.numeric(nrSessions),
        education = as.numeric(education),
        meal = as.numeric(meal),
        sleep = as.numeric(sleep),
        
        # Keep lifestyle "hours ago" variables as numeric but create categorical versions
        cigarette_raw = as.numeric(cigarette),
        coffee_raw = as.numeric(coffee),
        beer_raw = as.numeric(beer),
        drugs_raw = as.numeric(drugs),
        
        # Create numeric versions for analysis (99 → NA for "never")
        cigarette = ifelse(cigarette_raw == 99, NA, cigarette_raw),
        coffee = ifelse(coffee_raw == 99, NA, coffee_raw),
        beer = ifelse(beer_raw == 99, NA, beer_raw),
        drugs = ifelse(drugs_raw == 99, NA, drugs_raw),
        
        # Create categorical versions showing recent use vs never
        cigarette_cat = case_when(
            cigarette_raw == 99 ~ "Never",
            cigarette_raw <= 24 ~ "Within 24 hours",
            cigarette_raw > 24 ~ "More than 24 hours ago",
            TRUE ~ NA_character_
        ),
        coffee_cat = case_when(
            coffee_raw == 99 ~ "Never",
            coffee_raw <= 8 ~ "Within 8 hours",
            coffee_raw > 8 & coffee_raw < 99 ~ "More than 8 hours ago",
            TRUE ~ NA_character_
        ),
        beer_cat = case_when(
            beer_raw == 99 ~ "Never",
            beer_raw <= 24 ~ "Within 24 hours",
            beer_raw > 24 & beer_raw < 99 ~ "More than 24 hours ago",
            TRUE ~ NA_character_
        ),
        drugs_cat = case_when(
            drugs_raw == 99 ~ "Never",
            drugs_raw <= 24 ~ "Within 24 hours",
            drugs_raw > 24 & drugs_raw < 99 ~ "More than 24 hours ago",
            TRUE ~ NA_character_
        ),
        meal = as.numeric(meal),
        sleep = as.numeric(sleep),
        `Weight (kg)` = as.numeric(`Weight (kg)`),
        `Height (cm)` = as.numeric(`Height (cm)`),
        BDI_pre = as.numeric(BDI_pre),
        BDI_post = as.numeric(BDI_post),
        
        # ADHD scores
        ADHD_pre_Hyp_leading = as.numeric(ADHD_pre_Hyp_leading),
        ADHD_pre_Att_leading = as.numeric(ADHD_pre_Att_leading),
        ADHD_post_Hyp_leading = as.numeric(ADHD_post_Hyp_leading),
        ADHD_post_Att_leading = as.numeric(ADHD_post_Att_leading),
        
        # Cognitive performance variables
        avg_rt_oddb_CP = as.numeric(avg_rt_oddb_CP),
        avg_rt_oddb_FP = as.numeric(avg_rt_oddb_FP),
        n_oddb_CP = as.numeric(n_oddb_CP),
        n_oddb_FP = as.numeric(n_oddb_FP),
        n_oddb_CN = as.numeric(n_oddb_CN),
        n_oddb_FN = as.numeric(n_oddb_FN),
        avg_rt_wm_CP = as.numeric(avg_rt_wm_CP),
        avg_rt_wm_FP = as.numeric(avg_rt_wm_FP),
        n_wm_CP = as.numeric(n_wm_CP),
        n_wm_FP = as.numeric(n_wm_FP),
        n_wm_CN = as.numeric(n_wm_CN),
        n_wm_FN = as.numeric(n_wm_FN),
        
        # Create derived variables
        BMI = `Weight (kg)` / ((`Height (cm)` / 100)^2),
        BDI_change = BDI_post - BDI_pre,
        ADHD_Hyp_change = ADHD_post_Hyp_leading - ADHD_pre_Hyp_leading,
        ADHD_Att_change = ADHD_post_Att_leading - ADHD_pre_Att_leading,
        
        # Calculate percentage improvement for ADHD symptoms
        ADHD_Hyp_pct_improve = ifelse(ADHD_pre_Hyp_leading > 0, 
                                     ((ADHD_pre_Hyp_leading - ADHD_post_Hyp_leading) / ADHD_pre_Hyp_leading) * 100, 
                                     NA),
        ADHD_Att_pct_improve = ifelse(ADHD_pre_Att_leading > 0,
                                     ((ADHD_pre_Att_leading - ADHD_post_Att_leading) / ADHD_pre_Att_leading) * 100,
                                     NA),
        
        # Create clean responder definition (25% improvement in either domain)
        Responder_clean = case_when(
            # is.na(ADHD_pre_Hyp_leading) | is.na(ADHD_pre_Att_leading) ~ NA_character_,
            # is.na(ADHD_post_Hyp_leading) | is.na(ADHD_post_Att_leading) ~ NA_character_,
            Responder == "1" ~ "Responder",
            Responder == "0" ~ "Non-Responder",
            # Remitter == "1" ~ "Remitter",
            ADHD_Hyp_pct_improve >= 25 | ADHD_Att_pct_improve >= 25  ~ "Responder",
            ADHD_Hyp_pct_improve < 25 & ADHD_Att_pct_improve < 25 ~ "Non-Responder",
            TRUE ~ NA_character_
        ),
        
        # Create accuracy measures for cognitive tasks
        oddball_accuracy = n_oddb_CP / (n_oddb_CP + n_oddb_FP + n_oddb_CN + n_oddb_FN),
        wm_accuracy = n_wm_CP / (n_wm_CP + n_wm_FP + n_wm_CN + n_wm_FN),
        
        # Categorical variables
        well = factor(
            case_when(well == "-2" ~ "horrible",
                     well == "-1" ~ "less than normal", 
                     well == "1" ~ "normal",
                     well == "2" ~ "better than normal",
                     well == "3" ~ "awesome",
                     TRUE ~ as.character(well)),
            levels = c("horrible", "less than normal", "normal", "better than normal", "awesome"),
            ordered = TRUE
        ),
        vision = factor(vision),
        hearing = factor(hearing),
        
        # Create group variables
        treatment = ifelse(is.na(ADHD_pre_Hyp_leading), "No", "Yes"),
        group = case_when(
            indication == "HEALTHY" ~ "Healthy Control",
            indication == "ADHD" & is.na(ADHD_pre_Hyp_leading) ~ "ADHD (No Treatment)",
            indication == "ADHD" & !is.na(ADHD_pre_Hyp_leading) ~ "ADHD + Neurofeedback",
            TRUE ~ "Other"
        ),
        
        # Age groups
        age_group = case_when(
            age < 18 ~ "Children & Adolescents (<18 years)",
            age >= 18 & age < 60 ~ "Adults (18-59 years)",
            age >= 60 ~ "Older Adults (60+ years)",
            is.na(age) ~ NA_character_,
            TRUE ~ "Check age value"
        ),
        
        # Treatment response (clean definition based on 25% improvement)
        treatment_response = case_when(
            Responder_clean == "Responder" ~ "Responder",
            Responder_clean == "Non-Responder" ~ "Non-Responder", 
            TRUE ~ NA_character_
        )
    )
# Out:
# Warning message:
# “There were 6 warnings in `mutate()`.
# The first warning was:
# ℹ In argument: `Weight (kg) = as.numeric(`Weight (kg)`)`.
# Caused by warning:
# ! NAs introduced by coercion
# ℹ Run `dplyr::last_dplyr_warnings()` to see the 5 remaining warnings.”

# %%
colnames(demographics)
# Out:
#  [1] "participants_ID"       "indication"            "formal_status"
#  [4] "Dataset"               "sessSeason"            "sessTime"
#  [7] "Responder"             "Remitter"              "age"
# [10] "gender"                "nrSessions"            "cigarette"
# [13] "coffee"                "beer"                  "drugs"
# [16] "education"             "meal"                  "sleep"
# [19] "well"                  "vision"                "hearing"
# [22] "Weight (kg)"           "Height (cm)"           "BDI_pre"
# [25] "BDI_post"              "ADHD_pre_Hyp_leading"  "ADHD_pre_Att_leading"
# [28] "ADHD_post_Hyp_leading" "ADHD_post_Att_leading" "NF Protocol"
# [31] "rTMS PROTOCOL"         "avg_rt_oddb_CP"        "avg_rt_oddb_FP"
# [34] "n_oddb_CP"             "n_oddb_FP"             "n_oddb_CN"
# [37] "n_oddb_FN"             "avg_rt_wm_CP"          "avg_rt_wm_FP"
# [40] "n_wm_CP"               "n_wm_FP"               "n_wm_CN"
# [43] "n_wm_FN"               "cigarette_raw"         "coffee_raw"
# [46] "beer_raw"              "drugs_raw"             "cigarette_cat"
# [49] "coffee_cat"            "beer_cat"              "drugs_cat"
# [52] "BMI"                   "BDI_change"            "ADHD_Hyp_change"
# [55] "ADHD_Att_change"       "ADHD_Hyp_pct_improve"  "ADHD_Att_pct_improve"
# [58] "Responder_clean"       "oddball_accuracy"      "wm_accuracy"
# [61] "treatment"             "group"                 "age_group"
# [64] "treatment_response"

# %%
fwrite(demographics, "TDBRAIN_participants_demographics_all.csv")

# %%
demographics %>%
    select(-c(cigarette_raw, coffee_raw, beer_raw, drugs_raw, BMI, Responder_clean)) %>%
    fwrite("TDBRAIN_participants_demographics_cleaned.csv")

# %% [markdown]
# ## Demographics by Group

# %%
table1_vars <- c("age", "gender", "age_group", "BMI", "education", "sleep", 
                "well", "vision", "hearing", 
                "cigarette", "coffee", "beer", "drugs",  # numeric versions
                "cigarette_cat", "coffee_cat", "beer_cat", "drugs_cat",  # categorical versions
                "BDI_pre", "ADHD_pre_Hyp_leading", "ADHD_pre_Att_leading",
                "nrSessions", "NF Protocol")

table1_categorical <- c("gender", "age_group", "well", "vision", "hearing", "NF Protocol", 
                      "cigarette_cat", "coffee_cat", "beer_cat", "drugs_cat")

table1 <- CreateTableOne(
    vars = table1_vars,
    strata = "group",
    data = demographics,
    factorVars = table1_categorical,
    test = TRUE
)
# Out:
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in min(x, na.rm = TRUE):
# “no non-missing arguments to min; returning Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in max(x, na.rm = TRUE):
# “no non-missing arguments to max; returning -Inf”
# Warning message in StdDiff(variable = var, group = strataVar):
# “Variable has only NA's in at least one stratum. na.rm turned off.”
# Warning message in StdDiff(variable = var, group = strataVar):
# “Variable has only NA's in at least one stratum. na.rm turned off.”
# Warning message in StdDiff(variable = var, group = strataVar):
# “Variable has only NA's in at least one stratum. na.rm turned off.”
# Warning message in StdDiff(variable = var, group = strataVar):
# “Variable has only NA's in at least one stratum. na.rm turned off.”
# Warning message in StdDiff(variable = var, group = strataVar):
# “Variable has only NA's in at least one stratum. na.rm turned off.”
# Warning message in StdDiff(variable = var, group = strataVar):
# “Variable has only NA's in at least one stratum. na.rm turned off.”

# %%
table1
# Out:
#                                        Stratified by group
#                                         ADHD (No Treatment)
#   n                                       133
#   age (mean (SD))                       21.60 (14.47)
#   gender = 1 (%)                           93 ( 69.9)
#   age_group (%)
#      Adults (18-59 years)                  58 ( 43.9)
#      Children & Adolescents (<18 years)    74 ( 56.1)
#      Older Adults (60+ years)               0 (  0.0)
#   BMI (mean (SD))                       20.05 (4.77)
#   education (mean (SD))                  8.87 (6.02)
#   sleep (mean (SD))                      8.01 (2.26)
#   well (%)
#      horrible                               1 (  0.8)
#      less than normal                       9 (  6.8)
#      normal                               109 ( 82.0)
#      better than normal                     9 (  6.8)
#      awesome                                5 (  3.8)
#   vision = 0 (%)                          133 (100.0)
#   hearing = 0 (%)                         133 (100.0)
#   cigarette (mean (SD))                  5.19 (2.58)
#   coffee (mean (SD))                     6.27 (2.80)
#   beer (mean (SD))                      13.42 (2.32)
#   drugs (mean (SD))                      5.23 (6.46)
#   cigarette_cat = Within 24 hours (%)      21 ( 15.8)
#   coffee_cat (%)
#      More than 8 hours ago                 31 ( 23.3)
#      Never                                 67 ( 50.4)
#      Within 8 hours                        35 ( 26.3)
#   beer_cat = Within 24 hours (%)           24 ( 18.0)
#   drugs_cat = Within 24 hours (%)          26 ( 19.5)
#   BDI_pre (mean (SD))                     NaN (NA)
#   ADHD_pre_Hyp_leading (mean (SD))        NaN (NA)
#   ADHD_pre_Att_leading (mean (SD))        NaN (NA)
#   nrSessions (mean (SD))                 1.06 (0.24)
#   NF Protocol (%)
#      1                                      0 (  NaN)
#      2                                      0 (  NaN)
#      3                                      0 (  NaN)
#                                        Stratified by group
#                                         ADHD + Neurofeedback Healthy Control
#   n                                        71                   47
#   age (mean (SD))                       26.02 (14.48)        32.20 (13.66)
#   gender = 1 (%)                           43 ( 60.6)           16 ( 34.0)
#   age_group (%)
#      Adults (18-59 years)                  44 ( 62.9)           36 ( 97.3)
#      Children & Adolescents (<18 years)    26 ( 37.1)            0 (  0.0)
#      Older Adults (60+ years)               0 (  0.0)            1 (  2.7)
#   BMI (mean (SD))                         NaN (NA)           23.67 (3.05)
#   education (mean (SD))                 11.39 (5.69)         15.55 (2.32)
#   sleep (mean (SD))                      7.44 (2.11)          7.00 (1.62)
#   well (%)
#      horrible                               0 (  0.0)            1 (  2.1)
#      less than normal                      12 ( 17.1)           10 ( 21.3)
#      normal                                49 ( 70.0)           32 ( 68.1)
#      better than normal                     8 ( 11.4)            3 (  6.4)
#      awesome                                1 (  1.4)            1 (  2.1)
#   vision = 0 (%)                           71 (100.0)           47 (100.0)
#   hearing = 0 (%)                          71 (100.0)           47 (100.0)
#   cigarette (mean (SD))                  6.35 (3.15)          4.00 (2.83)
#   coffee (mean (SD))                     6.58 (2.93)          5.91 (2.91)
#   beer (mean (SD))                      12.78 (3.83)         12.15 (2.83)
#   drugs (mean (SD))                      6.67 (7.91)          0.48 (2.69)
#   cigarette_cat = Within 24 hours (%)      20 ( 28.2)            5 ( 10.6)
#   coffee_cat (%)
#      More than 8 hours ago                 20 ( 28.2)           14 ( 29.8)
#      Never                                 31 ( 43.7)           15 ( 31.9)
#      Within 8 hours                        20 ( 28.2)           18 ( 38.3)
#   beer_cat = Within 24 hours (%)           18 ( 25.4)           20 ( 42.6)
#   drugs_cat = Within 24 hours (%)           9 ( 12.7)           31 ( 66.0)
#   BDI_pre (mean (SD))                   21.82 (10.86)          NaN (NA)
#   ADHD_pre_Hyp_leading (mean (SD))       5.56 (2.21)           NaN (NA)
#   ADHD_pre_Att_leading (mean (SD))       7.06 (1.61)           NaN (NA)
#   nrSessions (mean (SD))                 1.13 (0.34)          1.00 (0.00)
#   NF Protocol (%)
#      1                                     55 ( 77.5)            0 (  NaN)
#      2                                      8 ( 11.3)            0 (  NaN)
#      3                                      8 ( 11.3)            0 (  NaN)
#                                        Stratified by group
#                                         Other          p      test
#   n                                         1
#   age (mean (SD))                       37.44 (NA)         NA
#   gender = 1 (%)                            0 (  0.0)  <0.001
#   age_group (%)                                        <0.001
#      Adults (18-59 years)                   1 (100.0)
#      Children & Adolescents (<18 years)     0 (  0.0)
#      Older Adults (60+ years)               0 (  0.0)
#   BMI (mean (SD))                         NaN (NA)      0.021
#   education (mean (SD))                 14.00 (NA)         NA
#   sleep (mean (SD))                      7.00 (NA)         NA
#   well (%)                                              0.342
#      horrible                               0 (  0.0)
#      less than normal                       0 (  0.0)
#      normal                                 1 (100.0)
#      better than normal                     0 (  0.0)
#      awesome                                0 (  0.0)
#   vision = 0 (%)                            1 (100.0)      NA
#   hearing = 0 (%)                           1 (100.0)      NA
#   cigarette (mean (SD))                  2.00 (NA)         NA
#   coffee (mean (SD))                     2.00 (NA)         NA
#   beer (mean (SD))                        NaN (NA)      0.379
#   drugs (mean (SD))                       NaN (NA)      0.001
#   cigarette_cat = Within 24 hours (%)       1 (100.0)   0.010
#   coffee_cat (%)                                        0.270
#      More than 8 hours ago                  0 (  0.0)
#      Never                                  0 (  0.0)
#      Within 8 hours                         1 (100.0)
#   beer_cat = Within 24 hours (%)            0 (  0.0)   0.009
#   drugs_cat = Within 24 hours (%)           0 (  0.0)  <0.001
#   BDI_pre (mean (SD))                   32.00 (NA)         NA
#   ADHD_pre_Hyp_leading (mean (SD))       9.00 (NA)         NA
#   ADHD_pre_Att_leading (mean (SD))       5.00 (NA)         NA
#   nrSessions (mean (SD))                 1.00 (NA)         NA
#   NF Protocol (%)                                         NaN
#      1                                      0 (  0.0)
#      2                                      0 (  0.0)
#      3                                      1 (100.0)

# %% [markdown]
# ## Cognitive Performance + Treatment Response

# %%
cognitive_data <- demographics %>%
    filter(indication == "ADHD") %>%
    select(group, treatment_response, 
           # Oddball task
           avg_rt_oddb_CP, avg_rt_oddb_FP, oddball_accuracy,
           # Working memory task
           avg_rt_wm_CP, avg_rt_wm_FP, wm_accuracy,
           # Treatment outcomes
           ADHD_pre_Hyp_leading, ADHD_post_Hyp_leading, ADHD_Hyp_change,
           ADHD_pre_Att_leading, ADHD_post_Att_leading, ADHD_Att_change,
           BDI_pre, BDI_post, BDI_change,
           nrSessions, Responder, Remitter)

table3_vars <- c("avg_rt_oddb_CP", "avg_rt_oddb_FP", "oddball_accuracy",
                "avg_rt_wm_CP", "avg_rt_wm_FP", "wm_accuracy",
                "ADHD_pre_Hyp_leading", "ADHD_post_Hyp_leading", "ADHD_Hyp_change", "ADHD_Hyp_pct_improve",
                "ADHD_pre_Att_leading", "ADHD_post_Att_leading", "ADHD_Att_change", "ADHD_Att_pct_improve",
                "BDI_pre", "BDI_post", "BDI_change", "nrSessions")

table3 <- CreateTableOne(
    vars = table3_vars,
    data = cognitive_data,
    test = TRUE
)
# Out:
# Warning message in ModuleReturnVarsExist(vars, data):
# “The data frame does not have: ADHD_Hyp_pct_improve ADHD_Att_pct_improve  Dropped”
# Warning message in ModuleReturnVarsExist(vars, data):
# “These variables only have NA/NaN: avg_rt_oddb_CP avg_rt_oddb_FP avg_rt_wm_CP avg_rt_wm_FP wm_accuracy  Dropped”

# %%
table3
# Out:
#
#                                     Overall
#   n                                    204
#   oddball_accuracy (mean (SD))        0.16 (0.04)
#   ADHD_pre_Hyp_leading (mean (SD))    5.56 (2.21)
#   ADHD_post_Hyp_leading (mean (SD))   1.76 (2.19)
#   ADHD_Hyp_change (mean (SD))        -3.80 (2.57)
#   ADHD_pre_Att_leading (mean (SD))    7.06 (1.61)
#   ADHD_post_Att_leading (mean (SD))   2.55 (2.67)
#   ADHD_Att_change (mean (SD))        -4.54 (2.78)
#   BDI_pre (mean (SD))                21.82 (10.86)
#   BDI_post (mean (SD))                8.00 (7.74)
#   BDI_change (mean (SD))            -14.33 (7.72)
#   nrSessions (mean (SD))              1.08 (0.28)

# %% [markdown]
# ## Baseline Predictors of Treatment Success (Neurofeedback subset only)

# %%
treatment_data <- demographics %>%
    filter(group == "ADHD + Neurofeedback") %>%
    select(treatment_response, age, gender, BMI, education,
           # Baseline clinical measures
           ADHD_pre_Hyp_leading, ADHD_pre_Att_leading, BDI_pre,
           # Baseline cognitive performance
           oddball_accuracy,
           # Lifestyle factors
           sleep, well, cigarette, coffee, beer, drugs,
            cigarette_cat, coffee_cat, beer_cat, drugs_cat,
           # Treatment details
           nrSessions, `NF Protocol`)

table4_vars <- c("age", "gender", "BMI", "education",
                "ADHD_pre_Hyp_leading", "ADHD_pre_Att_leading", "BDI_pre",
                "oddball_accuracy",
                "sleep", "well", 
                # "cigarette", "coffee", "beer", "drugs",  # numeric versions
                "cigarette_cat", "coffee_cat", "beer_cat", "drugs_cat",  # categorical versions
                "nrSessions", "NF Protocol")

table4_categorical <- c("gender", "well", "NF Protocol", 
                        "cigarette_cat", "coffee_cat", "beer_cat", "drugs_cat")

table4 <- CreateTableOne(
    vars = table4_vars,
    strata = "treatment_response",
    data = treatment_data,
    factorVars = table4_categorical,
    test = TRUE
)
# Out:
# Warning message in ModuleReturnVarsExist(vars, data):
# “These variables only have NA/NaN: BMI  Dropped”

# %%
table4
# Out:
#                                      Stratified by treatment_response
#                                       Non-Responder Responder     p      test
#   n                                      10            61
#   age (mean (SD))                     14.74 (9.32)  27.90 (14.38)  0.007
#   gender = 1 (%)                          5 (50.0)     38 (62.3)   0.698
#   education (mean (SD))                6.30 (5.06)  12.23 (5.37)   0.002
#   ADHD_pre_Hyp_leading (mean (SD))     5.40 (2.46)   5.59 (2.19)   0.803
#   ADHD_pre_Att_leading (mean (SD))     6.80 (2.25)   7.10 (1.49)   0.588
#   BDI_pre (mean (SD))                 29.00 (10.00) 21.20 (10.84)  0.238
#   oddball_accuracy (mean (SD))         0.17 (0.01)   0.17 (0.02)   0.857
#   sleep (mean (SD))                    7.70 (3.27)   7.39 (1.89)   0.673
#   well (%)                                                        <0.001
#      less than normal                     1 (11.1)     11 (18.0)
#      normal                               3 (33.3)     46 (75.4)
#      better than normal                   4 (44.4)      4 ( 6.6)
#      awesome                              1 (11.1)      0 ( 0.0)
#   cigarette_cat = Within 24 hours (%)     2 (20.0)     18 (29.5)   0.810
#   coffee_cat (%)                                                   0.359
#      More than 8 hours ago                4 (40.0)     16 (26.2)
#      Never                                5 (50.0)     26 (42.6)
#      Within 8 hours                       1 (10.0)     19 (31.1)
#   beer_cat = Within 24 hours (%)          2 (20.0)     16 (26.2)   0.978
#   drugs_cat = Within 24 hours (%)         2 (20.0)      7 (11.5)   0.812
#   nrSessions (mean (SD))               1.00 (0.00)   1.15 (0.36)   0.199
#   NF Protocol (%)                                                  0.348
#      1                                    8 (80.0)     47 (77.0)
#      2                                    2 (20.0)      6 ( 9.8)
#      3                                    0 ( 0.0)      8 (13.1)

# %% [markdown]
# ## Delete non-ADHD or healthy sample

# %%
keep_id <- participant %>% filter(indication == "ADHD" | formal_status == "ADHD" | indication == "HEALTHY") %>% pull(participants_ID)
length(keep_id)
# Out:
# [1] 252

# %%
all_id <- participant %>% pull(participants_ID)
delete_id <- setdiff(all_id, keep_id)

# %%
base_directory <- "/Users/tianyi/Library/Mobile Documents/com~apple~CloudDocs/TD_Brain_data/preprocessed"

for(id in keep_id) {
  dir_path <- file.path(base_directory, id)
  
  if(dir.exists(dir_path)) {
    flist = list.files(dir_path, pattern = "cleaned")
    # unlink(dir_path, recursive = TRUE)
    cat("✓ Deleted:", id, "\n")
  } else {
    cat("✗ Not found:", id, "\n")
  }
}
# Out:
# ✗ Not found: sub-87974617
# ✗ Not found: sub-87974621
# ✗ Not found: sub-87974665
# ✗ Not found: sub-87974709
# ✗ Not found: sub-87974841
# ✗ Not found: sub-87974973
# ✗ Not found: sub-87976193
# ✗ Not found: sub-87976369
# ✗ Not found: sub-87976413
# ✗ Not found: sub-87976457
# ✗ Not found: sub-87976461
# ✗ Not found: sub-87976505
# ✗ Not found: sub-87976641
# ✗ Not found: sub-87976773
# ✗ Not found: sub-87976817
# ✗ Not found: sub-87976953
# ✗ Not found: sub-87977045
# ✗ Not found: sub-87980197
# ✗ Not found: sub-87980241
# ✗ Not found: sub-87980329
# ✗ Not found: sub-87980373
# ✗ Not found: sub-87980417
# ✗ Not found: sub-87980689
# ✗ Not found: sub-87980869
# ✗ Not found: sub-87980913
# ✗ Not found: sub-87982225
# ✗ Not found: sub-87982849
# ✗ Not found: sub-88005441
# ✗ Not found: sub-88005485
# ✗ Not found: sub-88006297
# ✗ Not found: sub-88007109
# ✗ Not found: sub-88007241
# ✗ Not found: sub-88008997
# ✗ Not found: sub-88009309
# ✗ Not found: sub-88013089
# ✗ Not found: sub-88015117
# ✗ Not found: sub-88015117
# ✗ Not found: sub-88015565
# ✗ Not found: sub-88015881
# ✗ Not found: sub-88015925
# ✗ Not found: sub-88017361
# ✗ Not found: sub-88017633
# ✗ Not found: sub-88018533
# ✗ Not found: sub-88018673
# ✗ Not found: sub-88019033
# ✗ Not found: sub-88019165
# ✗ Not found: sub-88020065
# ✗ Not found: sub-88020065
# ✗ Not found: sub-88021365
# ✗ Not found: sub-88021365
# ✗ Not found: sub-88022177
# ✗ Not found: sub-88022537
# ✗ Not found: sub-88022677
# ✗ Not found: sub-88022853
# ✗ Not found: sub-88023213
# ✗ Not found: sub-88024205
# ✗ Not found: sub-88024205
# ✗ Not found: sub-88025237
# ✗ Not found: sub-88025325
# ✗ Not found: sub-88025421
# ✗ Not found: sub-88025553
# ✗ Not found: sub-88025785
# ✗ Not found: sub-88025785
# ✗ Not found: sub-88025917
# ✗ Not found: sub-88026545
# ✗ Not found: sub-88026949
# ✗ Not found: sub-88026949
# ✗ Not found: sub-88027577
# ✗ Not found: sub-88027581
# ✗ Not found: sub-88027805
# ✗ Not found: sub-88028161
# ✗ Not found: sub-88028433
# ✗ Not found: sub-88028613
# ✗ Not found: sub-88028661
# ✗ Not found: sub-88029425
# ✗ Not found: sub-88029557
# ✗ Not found: sub-88029733
# ✗ Not found: sub-88029921
# ✗ Not found: sub-88030505
# ✗ Not found: sub-88030729
# ✗ Not found: sub-88032753
# ✗ Not found: sub-88033289
# ✗ Not found: sub-88033289
# ✗ Not found: sub-88034013
# ✗ Not found: sub-88034057
# ✗ Not found: sub-88034057
# ✗ Not found: sub-88035273
# ✗ Not found: sub-88035317
# ✗ Not found: sub-88035949
# ✗ Not found: sub-88036081
# ✗ Not found: sub-88036081
# ✗ Not found: sub-88036265
# ✗ Not found: sub-88037609
# ✗ Not found: sub-88037801
# ✗ Not found: sub-88037977
# ✗ Not found: sub-88038025
# ✗ Not found: sub-88038473
# ✗ Not found: sub-88038609
# ✗ Not found: sub-88038697
# ✗ Not found: sub-88038789
# ✗ Not found: sub-88039193
# ✗ Not found: sub-88039281
# ✗ Not found: sub-88039685
# ✗ Not found: sub-88040185
# ✗ Not found: sub-88040317
# ✗ Not found: sub-88040541
# ✗ Not found: sub-88040853
# ✗ Not found: sub-88040901
# ✗ Not found: sub-88041081
# ✗ Not found: sub-88041257
# ✗ Not found: sub-88041305
# ✗ Not found: sub-88041349
# ✗ Not found: sub-88041441
# ✗ Not found: sub-88041485
# ✗ Not found: sub-88041529
# ✗ Not found: sub-88041849
# ✗ Not found: sub-88041893
# ✗ Not found: sub-88041941
# ✗ Not found: sub-88041985
# ✗ Not found: sub-88042161
# ✗ Not found: sub-88042389
# ✗ Not found: sub-88042565
# ✗ Not found: sub-88042661
# ✗ Not found: sub-88042705
# ✗ Not found: sub-88042793
# ✗ Not found: sub-88043017
# ✗ Not found: sub-88043197
# ✗ Not found: sub-88043961
# ✗ Not found: sub-88044093
# ✗ Not found: sub-88044141
# ✗ Not found: sub-88044189
# ✗ Not found: sub-88044233
# ✗ Not found: sub-88044277
# ✗ Not found: sub-88044321
# ✗ Not found: sub-88044453
# ✗ Not found: sub-88044997
# ✗ Not found: sub-88045129
# ✗ Not found: sub-88045173
# ✗ Not found: sub-88045217
# ✗ Not found: sub-88045489
# ✗ Not found: sub-88046077
# ✗ Not found: sub-88046213
# ✗ Not found: sub-88046305
# ✗ Not found: sub-88046393
# ✗ Not found: sub-88046753
# ✗ Not found: sub-88048729
# ✗ Not found: sub-88049001
# ✗ Not found: sub-88049313
# ✗ Not found: sub-88049585
# ✗ Not found: sub-88049673
# ✗ Not found: sub-88049761
# ✗ Not found: sub-88050081
# ✗ Not found: sub-88050529
# ✗ Not found: sub-88050573
# ✗ Not found: sub-88050669
# ✗ Not found: sub-88051073
# ✗ Not found: sub-88051337
# ✗ Not found: sub-88051837
# ✗ Not found: sub-88052057
# ✗ Not found: sub-88052241
# ✗ Not found: sub-88052421
# ✗ Not found: sub-88052645
# ✗ Not found: sub-88052825
# ✗ Not found: sub-88053005
# ✗ Not found: sub-88053137
# ✗ Not found: sub-88053185
# ✗ Not found: sub-88053273
# ✗ Not found: sub-88053361
# ✗ Not found: sub-88053453
# ✗ Not found: sub-88053545
# ✗ Not found: sub-88053589
# ✗ Not found: sub-88054129
# ✗ Not found: sub-88054173
# ✗ Not found: sub-88054533
# ✗ Not found: sub-88055121
# ✗ Not found: sub-88055301
# ✗ Not found: sub-88056021
# ✗ Not found: sub-88056693
# ✗ Not found: sub-88057101
# ✗ Not found: sub-88057189
# ✗ Not found: sub-88057461
# ✗ Not found: sub-88057781
# ✗ Not found: sub-88057869
# ✗ Not found: sub-88058001
# ✗ Not found: sub-88058361
# ✗ Not found: sub-88058589
# ✗ Not found: sub-88058633
# ✗ Not found: sub-88059305
# ✗ Not found: sub-88059397
# ✗ Not found: sub-88060561
# ✗ Not found: sub-88060609
# ✗ Not found: sub-88060789
# ✗ Not found: sub-88060833
# ✗ Not found: sub-88061325
# ✗ Not found: sub-88061417
# ✗ Not found: sub-88061829
# ✗ Not found: sub-88062189
# ✗ Not found: sub-88062861
# ✗ Not found: sub-88063129
# ✗ Not found: sub-88063217
# ✗ Not found: sub-88063265
# ✗ Not found: sub-88063849
# ✗ Not found: sub-88064345
# ✗ Not found: sub-88064433
# ✗ Not found: sub-88064477
# ✗ Not found: sub-88064749
# ✗ Not found: sub-88065021
# ✗ Not found: sub-88065285
# ✗ Not found: sub-88065921
# ✗ Not found: sub-88066909
# ✗ Not found: sub-88067357
# ✗ Not found: sub-88067449
# ✗ Not found: sub-88067493
# ✗ Not found: sub-88067541
# ✗ Not found: sub-88067629
# ✗ Not found: sub-88067717
# ✗ Not found: sub-88067853
# ✗ Not found: sub-88068797
# ✗ Not found: sub-88068841
# ✗ Not found: sub-88068929
# ✗ Not found: sub-88069113
# ✗ Not found: sub-88069245
# ✗ Not found: sub-88069289
# ✗ Not found: sub-88070105
# ✗ Not found: sub-88070417
# ✗ Not found: sub-88070825
# ✗ Not found: sub-88071185
# ✗ Not found: sub-88071273
# ✗ Not found: sub-88071361
# ✗ Not found: sub-88071453
# ✗ Not found: sub-88071545
# ✗ Not found: sub-88072037
# ✗ Not found: sub-88072625
# ✗ Not found: sub-88072845
# ✗ Not found: sub-88073029
# ✗ Not found: sub-88073205
# ✗ Not found: sub-88073337
# ✗ Not found: sub-88073521
# ✗ Not found: sub-88073653
# ✗ Not found: sub-88074021
# ✗ Not found: sub-88074381
# ✗ Not found: sub-88075053
# ✗ Not found: sub-88075101
# ✗ Not found: sub-88075593
# ✗ Not found: sub-88075681
# ✗ Not found: sub-88075821
# ✗ Not found: sub-88076173
# ✗ Not found: sub-88076357
# ✗ Not found: sub-88076489
# ✗ Not found: sub-88076805
# ✗ Not found: sub-88076989
# ✗ Not found: sub-88077393

# %%
have_id <- list.files("/Users/tianyi/Library/Mobile Documents/com~apple~CloudDocs/TD_Brain_data/preprocessed/")

# %%
length(have_id)
# Out:
# [1] 0
